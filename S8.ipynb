# %% [markdown]
# ### - Exercici 1
#
# Agafa un conjunt de dades de tema esportiu que t'agradi i normalitza els atributs categòrics en dummy. Estandaritza els atributs numèrics amb StandardScaler.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
wVb = pd.read_csv('cleanWVb.csv')
wVb.drop('Unnamed: 0', axis = 1, inplace = True)
wVb.sample(10)
# Out:
#                              name  height  weight  spike  block  position
# 91                Wanqianbai Rong     184      75    304    297    setter
# 5              Victoria Zhurbenko     186      67    306    297    middle
# 86                    Zixuan Meng     180      62    298    290    libero
# 48                   Jovana Kocic     190      85    290    285    middle
# 27                    Yuka Kitsui     172      60    294    283  opposite
# 22                 Lyara Medeiros     184      67    297    285    setter
# 60   Leslie Angélica Lopez Flores     169      78    198    190    libero
# 42              Gergana Dimitrova     184      71    305    288      wing
# 109                  Nair Canessa     185      70    295    298    middle
# 8          Anastasiia Cheremisina     187      80    305    298      wing

# %% [markdown]
# We do not really need the names.

# %%
wVb.drop('name', axis=1, inplace = True)
wVb.sample(5)
# Out:
#      height  weight  spike  block  position
# 114     190      66    296    287  opposite
# 29      176      66    297    290    middle
# 134     176      54    280    279    libero
# 104     186      68    277    272    middle
# 119     179      70    300    285      wing

# %% [markdown]
# Let's make dummies of the positions

# %%
dum = pd.get_dummies(wVb['position'])
dum.head()
# Out:
#    libero  middle  opposite  setter  wing
# 0       0       1         0       0     0
# 1       0       0         0       1     0
# 2       0       0         0       0     1
# 3       1       0         0       0     0
# 4       0       0         0       1     0

# %% [markdown]
# Now, standarise numeric values.

# %%
df = wVb.drop('position', axis = 1)

scale = StandardScaler()
stdData = scale.fit_transform(df)
df2 = pd.DataFrame(stdData, columns = df.columns)
#All means must be 0
print(df2.mean())
#All std must be 1
print(df2.std())
# Out:
# height   -9.891078e-16
# weight    9.434955e-16
# spike    -5.100815e-16
# block    -1.777910e-16
# dtype: float64
# height    1.003515
# weight    1.003515
# spike     1.003515
# block     1.003515
# dtype: float64

# %%
finalDf = pd.concat([df2, dum], axis = 1)
finalDf
# Out:
#        height    weight     spike     block  libero  middle  opposite  setter  \
# 0    1.459941  1.535009  0.946415  0.886050       0       1         0       0
# 1    0.123997  0.310996  0.234113  0.255825       0       0         0       1
# 2    1.095593  0.446998  0.547526  0.615954       0       0         0       0
# 3   -0.604699 -0.913016  0.034669  0.075761       1       0         0       0
# 4    0.002548  0.174995  0.091653 -0.014271       0       0         0       1
# ..        ...       ...       ...       ...     ...     ...       ...     ...
# 138 -0.118902 -0.777015  0.234113  0.525922       0       0         0       0
# 139  0.974143 -0.369011 -0.107792  0.135783       0       0         0       0
# 140  0.366896 -0.505012  0.319589  0.585943       0       1         0       0
# 141  0.002548  0.582999  0.006177  0.135783       0       0         0       1
# 142  0.366896  0.174995  0.519034  0.826029       0       1         0       0
#
#      wing
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
# ..    ...
# 138     1
# 139     1
# 140     0
# 141     0
# 142     0
#
# [143 rows x 9 columns]

# %% [markdown]
# ### Exercici 2
#
# Continua amb el conjunt de dades de tema esportiu que t'agradi i aplica l'anàlisi de components principals.
# By applying PCA, we are building a new multidimensional space, where each individual will be placed. The position, or coordinates of this placement, in theory, better represent the differences between individuals, with the least amount of information.

# %%
from sklearn.decomposition import PCA

n_components = 6
cols = [f'PCA_{i}' for i in range(n_components)]
pca = PCA(n_components = n_components)
pcaArray = pca.fit_transform(finalDf)
dfPCA = pd.DataFrame(pcaArray, columns = cols)

# %%
exVar = pca.explained_variance_ratio_
cols = dfPCA.columns
for item in zip(cols, exVar):
    print(item[0], '=', f'{100*item[1]:.3f}%')

print('Explained total variance ratio', f'{exVar.sum()*100:.3f}%')
# Out:
# PCA_0 = 51.312%
# PCA_1 = 26.150%
# PCA_2 = 7.045%
# PCA_3 = 5.775%
# PCA_4 = 3.811%
# PCA_5 = 2.834%
# Explained total variance ratio 96.927%

# %% [markdown]
# So in our case, we should maybe go higher than a 3 dimensional space.
